# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Load Dataset

# %%
data=pd.read_excel("/content/ML Project - KNN Loan Applicant Credit Risk Analysis U 16955473070.xlsx")

# %%
data
# Out:
#         Age  Total Work Experience  Number of years in city  \
# 0     40.50                      2                        6
# 1     41.25                      5                        2
# 2     39.50                      5                        2
# 3     35.00                      1                        4
# 4     34.00                      3                        3
# ...     ...                    ...                      ...
# 8990  30.80                      3                        3
# 8991  31.83                      3                        6
# 8992  32.67                      2                        5
# 8993  37.00                      3                        3
# 8994  32.08                      1                        6
#
#       Cost to Request Ratio  Cibil score  Overdrafts past12months  \
# 0                  0.842666          594                        0
# 1                  0.791667          754                        0
# ...

# %% [markdown]
# ## Basic Information of dataset

# %%
data.head()
# Out:
#      Age  Total Work Experience  Number of years in city  \
# 0  40.50                      2                        6
# 1  41.25                      5                        2
# 2  39.50                      5                        2
# 3  35.00                      1                        4
# 4  34.00                      3                        3
#
#    Cost to Request Ratio  Cibil score  Overdrafts past12months  \
# 0               0.842666          594                        0
# 1               0.791667          754                        0
# 2               0.727273          779                        0
# 3               0.820232          818                        0
# 4               0.455581          853                        0
#
#    Total bounces past12months
# 0                           0
# 1                           0
# 2                           0
# 3                           0
# 4                           1

# %%
data.tail()
# Out:
#         Age  Total Work Experience  Number of years in city  \
# 8990  30.80                      3                        3
# 8991  31.83                      3                        6
# 8992  32.67                      2                        5
# 8993  37.00                      3                        3
# 8994  32.08                      1                        6
#
#       Cost to Request Ratio  Cibil score  Overdrafts past12months  \
# 8990               0.596748          763                        0
# 8991               0.986793          532                        0
# 8992               0.628330          590                        0
# 8993               0.797193          812                        0
# 8994               0.287659          817                        0
#
#       Total bounces past12months
# 8990                           0
# 8991                           0
# 8992                           0
# 8993                           0
# 8994                           0

# %%
data.sample()
# Out:
#        Age  Total Work Experience  Number of years in city  \
# 3271  42.0                      2                        4
#
#       Cost to Request Ratio  Cibil score  Overdrafts past12months  \
# 3271               1.174027          832                        0
#
#       Total bounces past12months
# 3271                           1

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8995 entries, 0 to 8994
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Age                         8995 non-null   float64
#  1   Total Work Experience       8995 non-null   int64
#  2   Number of years in city     8995 non-null   int64
#  3   Cost to Request Ratio       8995 non-null   float64
#  4   Cibil score                 8995 non-null   int64
#  5   Overdrafts past12months     8995 non-null   int64
#  6   Total bounces past12months  8995 non-null   int64
# dtypes: float64(2), int64(5)
# memory usage: 492.0 KB

# %%
data.describe()
# Out:
#                Age  Total Work Experience  Number of years in city  \
# count  8995.000000            8995.000000              8995.000000
# mean     38.808202               2.131073                 4.288160
# std      10.203371               0.892141                 1.269416
# min      18.100000               1.000000                 1.000000
# 25%      30.830000               1.000000                 3.000000
# 50%      37.200000               2.000000                 4.000000
# 75%      45.400000               3.000000                 5.000000
# max      83.800000               5.000000                 6.000000
#
#        Cost to Request Ratio  Cibil score  Overdrafts past12months  \
# count            8995.000000  8995.000000              8995.000000
# mean                0.831183   752.626570                 0.322068
# std                 0.490216    67.645792                 0.914998
# min                 0.008466   351.000000                 0.000000
# ...

# %% [markdown]
# ### Checking for null values

# %%
data.isnull().sum()
# Out:
# Age                           0
# Total Work Experience         0
# Number of years in city       0
# Cost to Request Ratio         0
# Cibil score                   0
# Overdrafts past12months       0
# Total bounces past12months    0
# dtype: int64

# %% [markdown]
# ## Scatter plot between age & Total Work Experience

# %%
plt.scatter(data["Age"],data["Total Work Experience"])
plt.xlabel("Age")
plt.ylabel("Total Work Experience")
# Out:
# Text(0, 0.5, 'Total Work Experience')

# %% [markdown]
# ## Box plot for age

# %%
plt.boxplot(data["Age"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x788ea4d42950>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x788ea4d42990>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x788ea5dfb3d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x788ea4f5b350>],
#  'fliers': [<matplotlib.lines.Line2D at 0x788ea5ca8710>],
#  'means': []}

# %% [markdown]
# ## Box Plot for Cibil Score

# %%
plt.boxplot(data["Cibil score"])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x788ea4c1fd50>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x788ea4c1c590>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x788ea4c1fb10>],
#  'medians': [<matplotlib.lines.Line2D at 0x788ea4f47bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x788ea4f474d0>],
#  'means': []}

# %% [markdown]
# ## Creating Target and Feature data

# %%
x=data.drop("Total bounces past12months",axis=1)
y=data["Total bounces past12months"]

# %%
x
# Out:
#         Age  Total Work Experience  Number of years in city  \
# 0     40.50                      2                        6
# 1     41.25                      5                        2
# 2     39.50                      5                        2
# 3     35.00                      1                        4
# 4     34.00                      3                        3
# ...     ...                    ...                      ...
# 8990  30.80                      3                        3
# 8991  31.83                      3                        6
# 8992  32.67                      2                        5
# 8993  37.00                      3                        3
# 8994  32.08                      1                        6
#
#       Cost to Request Ratio  Cibil score  Overdrafts past12months
# 0                  0.842666          594                        0
# 1                  0.791667          754                        0
# ...

# %%
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       1
#        ..
# 8990    0
# 8991    0
# 8992    0
# 8993    0
# 8994    0
# Name: Total bounces past12months, Length: 8995, dtype: int64

# %% [markdown]
# ### **Working with Model**

# %% [markdown]
# ## Splitting data in train & test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=44)

# %%
x_train
# Out:
#         Age  Total Work Experience  Number of years in city  \
# 6372  47.25                      1                        5
# 627   39.42                      2                        4
# 1701  37.50                      1                        6
# 5140  36.10                      2                        6
# 8316  41.00                      1                        6
# ...     ...                    ...                      ...
# 4180  33.30                      3                        3
# 2144  28.60                      2                        6
# 3971  29.25                      2                        6
# 571   33.11                      3                        6
# 3491  31.67                      1                        6
#
#       Cost to Request Ratio  Cibil score  Overdrafts past12months
# 6372               0.843133          804                        1
# 627                0.683423          835                        0
# ...

# %%
x_test
# Out:
#         Age  Total Work Experience  Number of years in city  \
# 2100  59.90                      1                        6
# 14    62.00                      1                        4
# 530   46.58                      2                        3
# 6650  45.90                      1                        3
# 873   42.60                      2                        4
# ...     ...                    ...                      ...
# 3890  32.50                      3                        5
# 3251  67.17                      3                        4
# 2546  32.10                      3                        4
# 3941  21.11                      3                        3
# 1408  53.83                      1                        3
#
#       Cost to Request Ratio  Cibil score  Overdrafts past12months
# 2100               0.485638          630                        1
# 14                 1.107879          764                        0
# ...

# %%
y_train
# Out:
# 6372    1
# 627     0
# 1701    0
# 5140    2
# 8316    0
#        ..
# 4180    0
# 2144    0
# 3971    0
# 571     0
# 3491    0
# Name: Total bounces past12months, Length: 7196, dtype: int64

# %%
y_test
# Out:
# 2100    7
# 14      0
# 530     0
# 6650    3
# 873     0
#        ..
# 3890    0
# 3251    0
# 2546    0
# 3941    0
# 1408    3
# Name: Total bounces past12months, Length: 1799, dtype: int64

# %% [markdown]
# ## Applying Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model=KNeighborsClassifier()
model.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=14)

# %% [markdown]
# ## Train Score

# %%
model.score(x_train,y_train)
# Out:
# 0.660366870483602

# %% [markdown]
# ## Test Score

# %%
model.score(x_test,y_test)
# Out:
# 0.6403557531962201

# %% [markdown]
# ## Y predict

# %%
y_pred=model.predict(x_test)

# %% [markdown]
# ## Accuracy Score

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.6403557531962201

# %% [markdown]
# ## Trying for 1 to 14 values for k

# %%
from sklearn.neighbors import KNeighborsClassifier

train=[]
test=[]
for i in range(1,15):
  model=KNeighborsClassifier(i)
  model.fit(x_train,y_train)
  train.append(model.score(x_train,y_train))
  test.append(model.score(x_test,y_test))

# %%
test
# Out:
# [0.5291828793774319,
#  0.6125625347415231,
#  0.6114508060033352,
#  0.6192329071706504,
#  0.6264591439688716,
#  0.6297943301834352,
#  0.6359088382434686,
#  0.6353529738743746,
#  0.6364647026125625,
#  0.6359088382434686,
#  0.6364647026125625,
#  0.6403557531962201,
#  0.6386881600889383,
#  0.6403557531962201]

# %%
train
# Out:
# [1.0,
#  0.7447192884936076,
#  0.7096998332406893,
#  0.6914952751528627,
#  0.6824624791550862,
#  0.6773207337409672,
#  0.6702334630350194,
#  0.6673151750972762,
#  0.6639799888827126,
#  0.6637020566981656,
#  0.6628682601445247,
#  0.6620344635908838,
#  0.6610617009449694,
#  0.660366870483602]

# %% [markdown]
# ## Plotting Graph for K from 1 to 14

# %%
import seaborn as sns
plt.figure(figsize=(5,5))
sns.lineplot(x=range(1,15),y=train,marker="o",label="Train_Score")
sns.lineplot(x=range(1,15),y=test,marker="o",label="Test_Score")
# Out:
# <Axes: >
